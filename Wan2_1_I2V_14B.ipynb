# %% [markdown]
# **PREPARE ENVIRONMENT**

# %% [markdown]
# - You can set **parameters_in_vram** to 10 or less to reduce the VRAM used, especially if you want to generate a video with a resolution greater than 480 by 832 or 832 by 480. The VRAM used depends on the value of **parameters_in_vram** and the resolutions of the input image & output video.
# - Setting **parameters_in_vram** to 15 with a video resolution of 480 by 832 will result in a generation time of approximately 10 minutes. Lower values of **parameters_in_vram** will result in longer generation times. Higher values can reduce the video generation time, but increase the risk of getting **Out of Memory Error**s.

# %%
# @title
# !git clone https://github.com/Isi-dev/DiffSynth-Studio.git
# %cd DiffSynth-Studio
# !pip install -e .
# !pip install "huggingface_hub[cli]"
# !apt-get install -y aria2
import os
from huggingface_hub import list_repo_files

repo_id = "Isi99999/Wan2.1-I2V-14B-480P"
all_files = list_repo_files(repo_id)
base_url = f"https://huggingface.co/{repo_id}/resolve/main/"

with open("file_list.txt", "w") as f:
    for file_path in all_files:
        full_url = f"{base_url}{file_path}"
        save_path = f"models/Wan-AI/Wan2.1-I2V-14B-480P/{file_path}"
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        f.write(f"{full_url}\n out={save_path}\n")
# !aria2c -x 16 -s 16 -i file_list.txt --continue=true --auto-file-renaming=false

print("✅ All models downloaded successfully!")

import torch
from diffsynth import ModelManager, WanVideoPipeline, VideoData, save_video

model_manager = ModelManager(device="cpu")
model_manager.load_models(
    ["models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth"],
    torch_dtype=torch.float16, # Image Encoder is loaded with float16
)
model_manager.load_models(
    [
        "models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors",
        "models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors",
        "models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors",
    ],
    torch_dtype=torch.torch.bfloat16, # You can set `torch_dtype=torch.float8_e4m3fn` or `torch_dtype=torch.bfloat16` to disable FP8 quantization.
)

pipe = WanVideoPipeline.from_model_manager(model_manager, torch_dtype=torch.bfloat16, device="cuda")
parameters_in_vram = 6 # @param {"type":"number"}
pipe.enable_vram_management(num_persistent_param_in_dit=parameters_in_vram*10**9) # You can set `num_persistent_param_in_dit` to a small number to reduce VRAM required.
print("✅ All models loaded successfully!")
# Out:
# Cloning into 'DiffSynth-Studio'...
# remote: Enumerating objects: 2859, done.
# remote: Counting objects: 100% (1317/1317), done.
# remote: Compressing objects: 100% (426/426), done.
# remote: Total 2859 (delta 1076), reused 891 (delta 891), pack-reused 1542 (from 1)
# Receiving objects: 100% (2859/2859), 11.23 MiB | 9.57 MiB/s, done.
# Resolving deltas: 100% (1840/1840), done.
# /content/DiffSynth-Studio
# Obtaining file:///content/DiffSynth-Studio
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.21.0+cu124)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (13.3.0)
# Collecting transformers==4.46.2 (from diffsynth==1.1.2)
#   Downloading transformers-4.46.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 4.5 MB/s eta 0:00:00
# Collecting controlnet-aux==0.0.7 (from diffsynth==1.1.2)
#   Downloading controlnet_aux-0.0.7.tar.gz (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.4/202.4 kB 25.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (2.37.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.5.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (5.29.4)
# Collecting modelscope (from diffsynth==1.1.2)
#   Downloading modelscope-1.24.1-py3-none-any.whl.metadata (39 kB)
# Collecting ftfy (from diffsynth==1.1.2)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (8.6.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (0.30.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (1.14.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (4.11.0.86)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (3.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (11.1.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (1.0.15)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (0.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.2->diffsynth==1.1.2)
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->diffsynth==1.1.2)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->diffsynth==1.1.2) (1.3.0)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.11/dist-packages (from cupy-cuda12x->diffsynth==1.1.2) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->diffsynth==1.1.2) (0.2.13)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]->diffsynth==1.1.2) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]->diffsynth==1.1.2) (5.9.5)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.11/dist-packages (from modelscope->diffsynth==1.1.2) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.2->diffsynth==1.1.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.2->diffsynth==1.1.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.2->diffsynth==1.1.2) (2025.1.31)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->controlnet-aux==0.0.7->diffsynth==1.1.2) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->diffsynth==1.1.2) (3.0.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->controlnet-aux==0.0.7->diffsynth==1.1.2) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->controlnet-aux==0.0.7->diffsynth==1.1.2) (0.4)
# Downloading transformers-4.46.2-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 65.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.2 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.4 MB/s eta 0:00:00
# Downloading modelscope-1.24.1-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 114.9 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 97.1 MB/s eta 0:00:00
# Building wheels for collected packages: controlnet-aux
#   Building wheel for controlnet-aux (setup.py) ... done
#   Created wheel for controlnet-aux: filename=controlnet_aux-0.0.7-py3-none-any.whl size=274344 sha256=e31d7db6a2b3eec9c4ed283b21c8226cb85bfe34b85dae93ede2899b25b2ef83
#   Stored in directory: /root/.cache/pip/wheels/08/a1/0f/79d1529bbc60d1598da66052a2c60a2a13e5ac462b5f990653
# Successfully built controlnet-aux
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ftfy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, modelscope, tokenizers, nvidia-cusolver-cu12, transformers, controlnet-aux, diffsynth
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.3
#     Uninstalling transformers-4.50.3:
#       Successfully uninstalled transformers-4.50.3
#   Running setup.py develop for diffsynth
# Successfully installed controlnet-aux-0.0.7 diffsynth-1.1.2 ftfy-6.3.1 modelscope-1.24.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 tokenizers-0.20.3 transformers-4.46.2
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.11/dist-packages (0.30.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (4.13.1)
# Collecting InquirerPy==0.3.4 (from huggingface_hub[cli])
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface_hub[cli])
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.50)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (2025.1.31)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.6 MB/s eta 0:00:00
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Installing collected packages: pfzy, InquirerPy
# Successfully installed InquirerPy-0.3.4 pfzy-0.3.4
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 30 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1,086 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1,513 kB in 2s (747 kB/s)
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 126213 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 04/08 12:18:47 [NOTICE] Downloading 15 item(s)
#
# 04/08 12:18:47 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/README.md
#
# 04/08 12:18:47 [NOTICE] CUID#11 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/996dbad030df09b0b3c8e764f0fb5a81b98b220ab89524d6a9369e9ed882791f?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27diffusion_pytorch_model.safetensors%3B+filename%3D%22diffusion_pytorch_model.safetensors%22%3B&Expires=1744118327&Policy=&Signature=BdckhfSgvlzlowkqdNsdFL4a6whAEuxmfbXtRxfEBUqkraeX3YUGsLKGoknQUE5M7G1daJdGM8v0bPJGzehrXkDbgCOa6OHwq7YRU4ewQHbQM-H3GmIyAVKz0FvcTWevArmYkw0pyqvpPqrG0NmGIzen64mWgVEJaRpYsyLUi09Ylc5Iqs-abXePZvPa4gWgKCi6QmEUVDS23yv%7E70CL5O4hnhNEFnDQvuKj8VBkOeSGDSf65rS%7E161i%7EdUIx7HJc2HwAehxIOJ2bblB1MxmUlfHA22E942SAeDEIkHymDSIj1%7Exhyumnrqfx3ug6f56TmjEGoWUisS7GSsUkYdmEQ__&Key-Pair-Id=K24J24Z295AEI9
#
# 04/08 12:18:47 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/config.json
#
# 04/08 12:18:47 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/.gitattributes
#
# 04/08 12:18:47 [NOTICE] CUID#13 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/e3909a67b780650b35cf529ac782ad2b6b26e6d1f849d3fbb6a872905f452458?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27spiece.model%3B+filename%3D%22spiece.model%22%3B&Expires=1744118327&Policy=&Signature=eLnEyzyRNwK-AyAKpKl-uaiUQj9fJFl8KbDBLNBItqAa%7EkH3FvIn0GF2JeRmQWk0UlxyXWib9ETNVNC5RiJzL0jle0pA-81Oqw-tmedKW8fH24OicxnH-2-2doUafDUc4G5BjgfY5pAlbmcvqTcCv6spnD25ECYJmaf-L4sfQpgIPr6%7EFUMxkMd89ipHGuQ4otIAOcYPLsntuitYhDa9SieiGYZJ8Sj7QPbPg2vDvPri-3LUHmBnSV0kSZHuZSAmqwQOQER0dhTceLvhoTwQylVzKz2nHTouAWSVqd0C2zusyDuGsfNNU95U4oNBGTS2Y5XecGHsXa4HtdRDRnnorw__&Key-Pair-Id=K24J24Z295AEI9
#
# 04/08 12:18:47 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/special_tokens_map.json
#
# 04/08 12:18:47 [NOTICE] CUID#14 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/6e197b4d3dbd71da14b4eb255f4fa91c9c1f2068b20a2de2472967ca3d22602b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27tokenizer
__&Key-Pair-Id=K24J24Z295AEI9
#
# 04/08 12:18:51 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/sentencepiece.bpe.model
#
# 04/08 12:18:51 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/special_tokens_map.json
#
# 04/08 12:18:51 [NOTICE] CUID#108 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/62c24cdc13d4c9952d63718d6c9fa4c287974249e16b7ade6d5a85e7bbb75626?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27tokenizer.json%3B+filename%3D%22tokenizer.json%22%3B&response-content-type=application%2Fjson&Expires=1744118331&Policy=...&Signature=Cn0%7E-H6UXL3M8AvpR0sxDuyDIxTBZNCJ5YiD6eGUQ7Kwl4W04dHBgI1tEtzI499K1J4sXLRo5gWAPmw8I38HDP4tGJjgBBeUCzwh9zE3VXvDa-Zww8Iv-YK3OOrC2emubTa30ZRx2tywipz%7E4qPjLQHr3NON6r3QYAyz6spzLxG8pjdDrUXlekAwJCMQSF%7EMMTZxNKviiGGP-ppMoFlCSbZDzMJN5XFgCijB2kPqeD4rd%7Evb8WSOrLKdecono9PwTud25gPs0P7YB170wyt2Xx0scD-sqYdD8w9d6pqMLfI61Rsbgn7zHOxv5nq0sukov3k1c%7EebmCIBGAz-OnzxUQ__&Key-Pair-Id=K24J24Z295AEI9
#
# 04/08 12:18:56 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer.json
#
# 04/08 12:18:56 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer_config.json
#
# 04/08 12:18:59 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors
#
# 04/08 12:19:40 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
#  *** Download Progress Summary as of Tue Apr  8 12:19:50 2025 ***
# =
# [#b82320 6.4GiB/15GiB(40%) CN:16 DL:148MiB ETA:1m5s]
# FILE: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
# -
# [#51745f 6.1GiB/6.2GiB(97%) CN:16 DL:149MiB]
# FILE: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
# -
#
#
# 04/08 12:19:51 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
#
# 04/08 12:20:19 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7421d9|OK  |   3.7KiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/README.md
# 65f528|OK  |    34KiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/config.json
# 9d761e|OK  |   269KiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/.gitattributes
# 1320c3|OK  |   1.0MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/special_tokens_map.json
# c09174|OK  |    31MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/spiece.model
# 5ebc3e|OK  |   8.4MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer_config.json
# dcca98|OK  |    26MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer.json
# 660525|OK  |   7.1MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/sentencepiece.bpe.model
# f740d9|OK  |    34KiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/special_tokens_map.json
# a84b5a|OK  |   7.8MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer.json
# 818c48|OK  |    58KiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer_config.json
# 658c2c|OK  |    25MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors
# 038254|OK  |    90MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
# 51745f|OK  |   102MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
# b82320|OK  |   180MiB/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
#
# Status Legend:
# (OK):download completed.
# ✅ All models downloaded successfully!
# Loading models from: models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
#     model_name: wan_video_image_encoder model_class: WanImageEncoder
#     The following models are loaded: ['wan_video_image_encoder'].
# Loading models from: models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
#     model_name: wan_video_dit model_class: WanModel
#         This model is initialized with extra kwargs: {'has_image_input': True, 'patch_size': [1, 2, 2], 'in_dim': 36, 'dim': 5120, 'ffn_dim': 13824, 'freq_dim': 256, 'text_dim': 4096, 'out_dim': 16, 'num_heads': 40, 'num_layers': 40, 'eps': 1e-06}
#     The following models are loaded: ['wan_video_dit'].
# Loading models from: models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
#     model_name: wan_video_text_encoder model_class: WanTextEncoder
#     The following models are loaded: ['wan_video_text_encoder'].
# Loading models from: models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors
#     model_name: wan_video_vae model_class: WanVideoVAE
#     The following models are loaded: ['wan_video_vae'].
# Using wan_video_text_encoder from models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors.
# Using wan_video_dit from models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors.
# Using wan_video_vae from models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors.
# Using wan_video_image_encoder from models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth.
# ✅ All models loaded successfully!

# %% [markdown]
# **RUN TO UPLOAD IMAGE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 圖片儲存在 Google Drive
from PIL import Image
image_path = '/content/grace1.png'
image = Image.open(image_path).convert("RGB")

print("✅ Image loaded successfully:", image.size)
# Out:
# ✅ Image loaded successfully: (1024, 1536)

# %% [markdown]
# **RUN IMAGE TO VIDEO**

# %%
prompt = "女友風格，對鏡頭互動" # @param {type:"string"}
sample_steps = 20 # @param {"type":"number"}30
Instruction = "choose from '720*1280', '1280*720', '480*832', '832*480', '1024*1024 for output video's width & height." # @param {"type":"string"}
width = 512 # @param {"type":"number"}
height = 768 # @param {"type":"number"}
num_frames = 81 # @param {"type":"number"}81
seed = 1 # @param {"type":"number"}

# Generate video from text prompt and Image
video = pipe(
    prompt=prompt,
    negative_prompt="色调艳丽，过曝，静态，细节模糊不清，字幕，风格，作品，画作，画面，静止，整体发灰，最差质量，低质量，JPEG压缩残留，丑陋的，残缺的，多余的手指，画得不好的手部，画得不好的脸部，畸形的，毁容的，形态畸形的肢体，手指融合，静止不动的画面，杂乱的背景，三条腿，背景人很多，倒着走",
    input_image=image,
    height = height,
    width = width,
    num_frames=num_frames,
    num_inference_steps=sample_steps,
    seed=seed, tiled=True
)

# # Save the generated video, fps=15, quality=5
save_video(video, "video.mp4", fps=15, quality=5)

from IPython.display import display as displayVid, Video as outVid
import os

# Function to display video
def show_video(video_path):
    if os.path.exists(video_path):
        displayVid(outVid(video_path, embed=True))
    else:
        print(f"Error: {video_path} not found!")

# Show the video
show_video("video.mp4")
# Out:
#  65%|██████▌   | 13/20 [15:33<08:22, 71.74s/it]

# %% [markdown]
# **UTILITY FUNCTIONS**

# %%
# Download file
from google.colab import files

files.download('./video.mp4')

# %%
# terminate a Colab session
import os
import time

import torch

# Force PyTorch to use CPU
device = torch.device("cpu")

# Example: Moving a tensor to the CPU (if needed)
tensor = torch.randn(3, 3).to(device)
print(f"Running on device: {device}")
# Out:
# Running on device: cpu

# %%
# Use L4 GPU, release VRAM
import torch
torch.cuda.empty_cache()
torch.cuda.ipc_collect()
# %env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
